# %%
class Account():
  def __init__(self,balance):
    self.balance=balance

  def withdraw(self,amount):
    self.balance=self.balance - amount
    print(f"New Balance is {self.balance} and amount withdrawn is {amount}")

  def deposit(self,amount):
    self.balance=self.balance + amount
    print(f"New Balance is {self.balance} and amount deposited is {amount}")

# %%
class Account():
    def __init__(self,balance,first_name,last_name,age,address,Aadhar_no):
        
        self.balance=balance
        self.first_name=first_name
        self.last_name=last_name
        self.age=age
        self.address=address
        self.Aadhar_no=Aadhar_no

# %%
p1 = Account(balance = 50)

# %%
person1 = Account(balance=400,
                 first_name="abc",
                 last_name="def",
                 age=18,
                 address="foba",
                 Aadhar_no=12345)

# %%
import csv 
import json

class Reader():
  def __init__(self,path):
    self.path = path

  def read_flat_file(self):
    with open(self, path, "r",encoding ='utf-8') as f:
      reader = csv.DictReader(f,delimiter=delimiter)
      for row in reader:
        data.append(row)
    return data

  def read_json(self):
    with open(self.path, "r",encoding ='utf-8') as f:
      raw_json = f.read()
    json_data = json.loads(raw_json)
    return json_data

# %%
path = "/content/sample_json.json"
r =Reader(path)

# %%
r.read_json()
# Out:
# {'bbox': [-155.46516418457,
#   19.202167510986,
#   -0.09,
#   -97.93731689,
#   63.24,
#   105.6],
#  'features': [{'geometry': {'coordinates': [-155.451171875,
#      19.2175006866455,
#      35.3600006103516],
#     'type': 'Point'},
#    'id': 'hv72595567',
#    'properties': {'alert': None,
#     'cdi': None,
#     'code': '72595567',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72595567.geojson',
#     'dmin': None,
#     'felt': None,
#     'gap': 113,
#     'ids': ',hv72595567,',
#     'mag': 2.1500001,
#     'magType': 'md',
#     'mmi': None,
#     'net': 'hv',
#     'nst': 44,
#     'place': '3 km ENE of Pāhala, Hawaii',
#     'rms': 0.100000001,
#     'sig': 71,
#     'sources': ',hv,',
#     'status': 'automatic',
#     'time': 1626859250480,
#     'title': 'M 2.2 - 3 km ENE of Pāhala, Hawaii',
#     'tsunami': 0,
#     'type': 'earthquake',
#     'types': ',origin,phase-data,',
#     'tz': None,
#     'updated': 1626859447300,
# ...

# %%
path = "/content/file_data.csv"
r =Reader(path)

# %%
import pandas as pd

# %%
path = "/content/athlete_events.csv"
data = pd.read_csv(path)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games    Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992.0
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012.0
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data['Name'] #single column access
# Out:
# 0                         A Dijiang
# 1                          A Lamusi
# 2               Gunnar Nielsen Aaby
# 3              Edgar Lindenau Aabye
# 4          Christine Jacoba Aaftink
#                     ...
# 259228    Claudia Verdicchio-Krause
# 259229    Claudia Verdicchio-Krause
# 259230    Claudia Verdicchio-Krause
# 259231    Claudia Verdicchio-Krause
# 259232                           Cl
# Name: Name, Length: 259233, dtype: object

# %%
data['Name'].head(2)
# Out:
# 0    A Dijiang
# 1     A Lamusi
# Name: Name, dtype: object

# %%
data[['Name','Age']]
# Out:
#                              Name   Age
# 0                       A Dijiang  24.0
# 1                        A Lamusi  23.0
# 2             Gunnar Nielsen Aaby  24.0
# 3            Edgar Lindenau Aabye  34.0
# 4        Christine Jacoba Aaftink  21.0
# ...                           ...   ...
# 259228  Claudia Verdicchio-Krause    29
# 259229  Claudia Verdicchio-Krause    29
# 259230  Claudia Verdicchio-Krause    33
# 259231  Claudia Verdicchio-Krause    37
# 259232                         Cl   NaN
#
# [259233 rows x 2 columns]

# %%
data.shape #rows and columns
# Out:
# (259233, 15)

# %%
data[['Name','Event','Medal']].head(100)
# Out:
#                                   Name                             Event Medal
# 0                            A Dijiang       Basketball Men's Basketball   NaN
# 1                             A Lamusi      Judo Men's Extra-Lightweight   NaN
# 2                  Gunnar Nielsen Aaby           Football Men's Football   NaN
# 3                 Edgar Lindenau Aabye       Tug-Of-War Men's Tug-Of-War  Gold
# 4             Christine Jacoba Aaftink  Speed Skating Women's 500 metres   NaN
# ..                                 ...                               ...   ...
# 95                Olav Augunson Aarnes         Athletics Men's High Jump   NaN
# 96                 Mika Lauri Aarnikka   Sailing Men's Two Person Dinghy   NaN
# 97                 Mika Lauri Aarnikka   Sailing Men's Two Person Dinghy   NaN
# 98  Jamale (Djamel-) Aarrass (Ahrass-)      Athletics Men's 1,500 metres   NaN
# 99              Dagfinn Sverre Aarskog              Bobsleigh Men's Four   NaN
#
# [100 rows x 3 columns]

# %%
data[data['Games'] == "1992 Summer"].head()
# Out:
#      ID                   Name Sex   Age  Height  Weight     Team  NOC  \
# 0     1              A Dijiang   M  24.0   180.0    80.0    China  CHN
# 96   33    Mika Lauri Aarnikka   M  24.0   187.0    76.0  Finland  FIN
# 118  43  Morten Gjerdrum Aasen   M  34.0   185.0    75.0   Norway  NOR
# 137  50             Arvi Aavik   M  22.0   185.0   106.0  Estonia  EST
# 160  64         M'Bairo Abakar   M  31.0     NaN     NaN     Chad  CHA
#
#            Games    Year  Season       City          Sport  \
# 0    1992 Summer  1992.0  Summer  Barcelona     Basketball
# 96   1992 Summer  1992.0  Summer  Barcelona        Sailing
# 118  1992 Summer  1992.0  Summer  Barcelona  Equestrianism
# 137  1992 Summer  1992.0  Summer  Barcelona      Wrestling
# 160  1992 Summer  1992.0  Summer  Barcelona           Judo
#
#                                        Event Medal
# 0                Basketball Men's Basketball   NaN
# 96           Sailing Men's Two Person Dinghy   NaN
# ...

# %%
data[data['Team'] == "China"].head()
# Out:
#         ID           Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 0        1      A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer
# 1        2       A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer
# 1072   602  Abudoureheman   M  22.0   182.0    75.0  China  CHN  2000 Summer
# 2611  1463      Ai Linuer   M  25.0   160.0    62.0  China  CHN  2004 Summer
# 2612  1464      Ai Yanhan   F  14.0   168.0    54.0  China  CHN  2016 Summer
#
#         Year  Season            City       Sport  \
# 0     1992.0  Summer       Barcelona  Basketball
# 1     2012.0  Summer          London        Judo
# 1072  2000.0  Summer          Sydney      Boxing
# 2611  2004.0  Summer          Athina   Wrestling
# 2612  2016.0  Summer  Rio de Janeiro    Swimming
#
#                                          Event Medal
# 0                  Basketball Men's Basketball   NaN
# 1                 Judo Men's Extra-Lightweight   NaN
# ...

# %%
data.query("Team == 'China'").head()
# Out:
#         ID           Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 0        1      A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer
# 1        2       A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer
# 1072   602  Abudoureheman   M  22.0   182.0    75.0  China  CHN  2000 Summer
# 2611  1463      Ai Linuer   M  25.0   160.0    62.0  China  CHN  2004 Summer
# 2612  1464      Ai Yanhan   F  14.0   168.0    54.0  China  CHN  2016 Summer
#
#         Year  Season            City       Sport  \
# 0     1992.0  Summer       Barcelona  Basketball
# 1     2012.0  Summer          London        Judo
# 1072  2000.0  Summer          Sydney      Boxing
# 2611  2004.0  Summer          Athina   Wrestling
# 2612  2016.0  Summer  Rio de Janeiro    Swimming
#
#                                          Event Medal
# 0                  Basketball Men's Basketball   NaN
# 1                 Judo Men's Extra-Lightweight   NaN
# ...

# %%
data.query("Year == 1992").head()
# Out:
#     ID                      Name Sex   Age  Height  Weight           Team  \
# 0    1                 A Dijiang   M  24.0   180.0    80.0          China
# 6    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0    Netherlands
# 7    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0    Netherlands
# 10   6           Per Knut Aaland   M  31.0   188.0    75.0  United States
# 11   6           Per Knut Aaland   M  31.0   188.0    75.0  United States
#
#     NOC        Games    Year  Season         City                 Sport  \
# 0   CHN  1992 Summer  1992.0  Summer    Barcelona            Basketball
# 6   NED  1992 Winter  1992.0  Winter  Albertville         Speed Skating
# 7   NED  1992 Winter  1992.0  Winter  Albertville         Speed Skating
# 10  USA  1992 Winter  1992.0  Winter  Albertville  Cross Country Skiing
# 11  USA  1992 Winter  1992.0  Winter  Albertville  Cross Country Skiing
#
#                                        Event Medal
# ...

# %%
data.query("Age <= 26" and "Year ==1992").head()
# Out:
#     ID                      Name Sex   Age  Height  Weight           Team  \
# 0    1                 A Dijiang   M  24.0   180.0    80.0          China
# 6    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0    Netherlands
# 7    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0    Netherlands
# 10   6           Per Knut Aaland   M  31.0   188.0    75.0  United States
# 11   6           Per Knut Aaland   M  31.0   188.0    75.0  United States
#
#     NOC        Games    Year  Season         City                 Sport  \
# 0   CHN  1992 Summer  1992.0  Summer    Barcelona            Basketball
# 6   NED  1992 Winter  1992.0  Winter  Albertville         Speed Skating
# 7   NED  1992 Winter  1992.0  Winter  Albertville         Speed Skating
# 10  USA  1992 Winter  1992.0  Winter  Albertville  Cross Country Skiing
# 11  USA  1992 Winter  1992.0  Winter  Albertville  Cross Country Skiing
#
#                                        Event Medal
# ...

# %%
data.query("Team== 'China' or Team == 'Norway'").head()
# Out:
#     ID                Name Sex   Age  Height  Weight    Team  NOC  \
# 0    1           A Dijiang   M  24.0   180.0    80.0   China  CHN
# 1    2            A Lamusi   M  23.0   170.0    60.0   China  CHN
# 59  20  Kjetil Andr Aamodt   M  20.0   176.0    85.0  Norway  NOR
# 60  20  Kjetil Andr Aamodt   M  20.0   176.0    85.0  Norway  NOR
# 61  20  Kjetil Andr Aamodt   M  20.0   176.0    85.0  Norway  NOR
#
#           Games    Year  Season         City          Sport  \
# 0   1992 Summer  1992.0  Summer    Barcelona     Basketball
# 1   2012 Summer  2012.0  Summer       London           Judo
# 59  1992 Winter  1992.0  Winter  Albertville  Alpine Skiing
# 60  1992 Winter  1992.0  Winter  Albertville  Alpine Skiing
# 61  1992 Winter  1992.0  Winter  Albertville  Alpine Skiing
#
#                                Event   Medal
# 0        Basketball Men's Basketball     NaN
# 1       Judo Men's Extra-Lightweight     NaN
# 59      Alpine Skiing Men's Downhill     NaN
# ...

# %%
# ?data.sort_values

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games    Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992.0  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012.0  Summer     London           Judo
# 2  DEN  1920 Summer  1920.0  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900.0  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988.0  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data.dtypes
# Out:
# ID          int64
# Name       object
# Sex        object
# Age        object
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year      float64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
import pandas as pd

# %%
path = "/content/starbucks.csv"
data = pd.read_csv(path)
